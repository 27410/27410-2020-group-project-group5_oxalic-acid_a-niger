# %% [markdown]
# # Oxalic acid production with Aspergillus niger

# %% [markdown]
# ## 1. Introduction
#
# Oxalic acid has been of industrial importance ever since, traditionally obtained through chemical synthesis. However, the chemical synthesis affords the use of harsh chemicals like sulphuric acid and high temperatures up to 360 °C leading to a high energy consumption. Biological production of oxalic acid could provide a sustainable alternative with the possibility of using waste products like cashew apple juice as substrate [1]. However, major drawbacks are low yields and low productivity, mainly due the oxidation of glucose and loss of energy in unfavorable pathways [1].
# The overall aim of this project is to evaluate engineering strategies for the production of oxalic acid in the cell factory Aspergillus niger.

# %% [markdown]
# ### 1.1 Literature review of the compound
# Oxalic acid is a dicarboxylic acid with a molecular weight of 90,03 g/mol. The molecule resembles ethane with substitutions of carboxyl groups at positions 1 and 2 [2].
# Oxalic acid has several applications. The most common one is contribution in laundry detergents as the acid rinse, being responsible for converting insoluble iron compounds into soluble complex ions and thus removing dust such as rust and ink stains or removing scale from car radiators [3].
# It is also applied for bleaching clothes and in medicine it is used for further purifying chemicals or to dilute them [4].
#
# ![Oxalic acid structure.JPG](attachment:9cde8d91-7b61-4fbd-85f3-8ba1f663fc2e.JPG)
#
# Figure 1: Structure of oxalic acid [5]
#
# With the help of the Kegg database, Oxalic acid could be found in the glyoxylate and dicarboxylate metabolism of Aspergillus niger. There, two main routes to produce the metabolite Oxalic acid could be identified. Both routes are branch-offs from the TCA cycle. The first one is starting from the TCA-cycle intermediate Oxaloacetate, which is reduced to another intermediate of the TCA-cycle: Malate. This reaction is an anti-clockwise reaction of the TCA cycle. Thereafter, Malate is converted into Glyoxylate by reacting with CoA. Then, this Glyoxylate is oxidized into the desired Oxalate, which is catalyzed by an oxygen oxidoreductase.
#
# The other route starts two stages later in the TCA cycle going from Oxaloacetate to Citrate and then to Isocitrate, which is then split into Succinate and Glyoxylate which is mediated by the enzyme isocitrate glyoxylate-lyase.
# As mentioned above in the other route, the Glyoxylate is finally oxidized into Oxalate [6].
#
#
# The global market size for oxalic acid has been around 620 million USD in 2017 [7]. In 2019 the market was assumed to grow by roughly 177 million USD in the following year [8]. Driver for  a higher demand in the market is mostly China, but followed by Japan, US and Germany [8]. Depending on the desired purity, prices for Oxalic acid range from 0,5 - 1 USD/kg [9]. The price always hints towards the challenge of introducing a biotechnologically competing process: The product price is not much higher than the substrate cost (~0,1-0,2 USD/kg), therefore a cheap and efficient process is required [10].

# %% [markdown]
# ### 1.2 Literature review of the cell factory
# A. Niger counts itself among the most important biotechnological microorganisms. A. Niger has already been used biotechnologically for different products since many decades, so that much information about the metabolism and fermentation demands are already available . Moreover, it is well-known for the extracellular production of enzymes, mostly food enzymes, and citric acid in high yields.[6] This ability to secrete its products in high concentration into the fermentation medium can be considered as an advantage as well, since downstream costs are reduced as a cell disruption method is not required [11].
# A. Niger is used for biotransformations and has been utilized in that regard for the over-expression of food enzymes [11].
# Another advantage is that many products from A. Niger are characterized as GRAS products by the US-FDA [11].
#
# So, a number of several protease genes containing a secretion peptide could be identified, which pose a risk for product degradation in industrial fermentation. Moreover, genes were discovered for the production of the carcinogenic mycotoxins fumonisin and ochratoxin A. Even though a draft genome of A. Niger was published, only half of the discovered 14.165 ORF’s were functionally predictable. This ‘Black Box’ poses an issue to get a better understanding on the level of systems biology.
#
# There have been some studies about oxalic acid production in Aspergillus niger. An older study reported a product concentration of 33,8 g/l and a productivity of 4,1 g/l*d. Finally, they obtained a yield of 0,3 kg oxalic acid/kg sucrose [12]. More recent studies identified an oxalic acid overproducing mutant with a productivity of approximately 3 g/l*d and a final titer of 11 g/l. Highlight of this study is the oxalic acid overproducing phenotype, which had an increased yield of glucose on oxalic acid of 90 % compared to the wildtype. This was achieved by knocking out pH responding transcription factors. Therefore, manipulating transcription factors could be a solution to debottleneck production of oxalic acid in Aspergillus niger [13].
# In a more recent study researchers overexpressed the gene oahA, which is encoding the enzyme oxaloacetate hydrolase (EC 3.7.1.1). The overexpression leads to an increase of concentration from 15,6 g/l to 28,9 g/l compared to the unmodified strain. Finally, they reported a yield of 64,2 % of the maximum theoretical yield for glucose to oxalic acid . Therefore, an overexpression of that gene could further increase flux towards oxalic acid [14]. In a even more recent paper, a titer of 123 g/l oxalic acid was reached and a productivity of 17 g/l*d [1].
# In general, Aspergillus niger seems to be a promising cell factory for this compound.

# %% [markdown]
# ## 2. Problem definition

# %% [markdown]
# As an organic acid, Oxalic acid can be considered as a low value chemical, meaning having an abundant and cheap feedstock as well as great fermentation metrics is key to compete with the existing chemical processes. Therefore, as a rule of thumb, a final product titer of minimum 100 g/L at the end of fermentation is desired, which has already been achieved in Aspergillus niger fermentations by some research groups. However, the productivity has to be increased to at least 5 g/L*h. Productivity has, as presented previously already, been significantly lower than the desired value. Finally, the yield YSP has to be improved closer to the maximum theoretical yield considering sucrose as substrate. Highest achieved yield compared to the maximum theoretical yield was 64,2 %.
#
# To achieve an economically favourable process, different substrates and pH and gene knockouts, should be investigated with an optimized Aspergillus niger iJB1325 model [15].
#
# The metrics can be changed by trying different pH in the environment which could lead to more favorable conditions for Oxalic acid production.
# The yield of substrate on the product also seems to be a problem. Sucrose and also lactose were separately chosen as a carbon source in the reference [16]. However, especially for sucrose, this had the drawback of getting degraded into glucose at the beginning of the fermentation, which had an unfavorable consumption of the glucose and flux into gluconic acid as a consequence. Therefore, identifying the sucrose-degrading extracellular enzyme and knocking it out could be a promising approach. Since this could probably have a negative effect on the growth rate of the host as this enzyme could be essential for a specific pathway, an alternative approach could be to prevent the flux towards gluconic acid by knocking out genes involved in expressing the enzymes involved in the reactions of the pathway.

# %% [markdown]
# ## 3. *If Project category II:* Selection and assessment of existing GSM
# The model chosen for optimizing the production of oxalic acid in Aspergillus niger iJB1325 was chosen based on its date of publication and scope. This model resembles the newest genome-based model for Aspergillus niger, it was published in 2018. The given model is an updated version of the model iMA871 which was published in 2009. In general, the overall coverage of the genome-scale model and the assignment of genes to reactions was improved.  Special emphasis was also put on including modeling of recently discovered secondary metabolites and other proteins [15]. In total, the chosen model  iJB1325 extends the model iMA871 by 940 reactions, 777 metabolites and 454 genes resulting in a total number of 2320 reactions, 1818 metabolites and 1325 genes. Overall, the chosen model is considered the best choice because of having integrated big amounts of recent data which enables trustful simulations of flux distributions [15].
# Moreover, the GSM has been updated based on including data from literature, patents and several databases like BRENDA for instance.
# On top of that, two further models of A.niger have been partly integrated in the updated model iMA871, one is a de novo-generated based model on an advanced automated method , and one was published by Lu et al [17].
#
# As part of the model  iJB1325, 471 test cases have been implemented which can be run when updating the model, in order to evaluate if the different sources of data on which the model was built go hand in hand. Those tests entail presence/absence of growth on different C-and N-sources (371 cases), presence/absence of knockout-mutants (73 cases), overall system check like producing biomass precursors.
# Performing all tests yields a score of 79 % passing and 21% failing the tests. Most of those failures were due to unknown metabolic pathways (76,5 %), inconsistencies between different experiment data (15,3 %) and undefinable  reasons (8,2 %).
# The model is furthermore backed up with evidence from literature in different levels. All in all, 19 % of the reactions which are included in the model have direct experimental back-up, whereas 17 % of the reactions have a gene assigned which has strong similarities to genes encoding for certain characterized enzymes in closely related species, mostly A. nidulans and A.fumigatus. The remaining reactions were not able to be assigned to a gene or are taken over from the model iMA871 as best scores resulting from sequence similarity studies of characterized enzymes or domains.
# The date of publication, extended number of reactions,metabolites and genes (in relation of  iMA871) as well as the presence of validation tests and evidence from literature make this model a well-suited approach to perform metabolic studies for the production of oxalic acid in A. niger. The memote analysis of the GSM-model revealed that the model is excellent in consistency, but lacking metabolites, reactions, gene and SBO annotations. A total score of 46 % was reached [18]. The full report is supplemented in the repository as Memote full report.
#
# ![Memote score summary.JPG](attachment:f17b35c2-a3a6-4539-95cc-a143ea89a4b8.JPG)
#
# Figure 2: Memote total score

# %% [markdown]
# ### 4. Computer-Aided Cell Factory Engineering (<1500 words if Category II project; <500 words for Category I project)4
#
# How  we used our GSM to compute cell factory engineering strategies for Oxalic acid.
#
# # 4.0 Loading Model
#
# We load the Model into Github
#
# # 4.2 Validating Pathways
#
#     Computationally enumerate all potential production pathways to your chosen product (even if it is a native product) and score them by different metrics (yield, number of steps added,)
#
# ![image.png](attachment:5159f871-b7a7-4826-ab1e-b53374cab59d.png)
#
# Figure 3: Metabolic pathway for citric, gluconic and oxalic acid synthesis in Aspergillus niger
#
# Using Kegg we validated 3 main pathways that would led to Oxalic acid synthesis:
# ![image.png](attachment:964bc7b3-1ef4-4fe5-b81c-fe73c9ea04d3.png)
#
# Figure 4: Pathways according to the database KEGG [19]
#
# By analyzing the model, the model gives a reaction as an output with the ID: r51, which entails the hydrolysis of oxlaoacetate to acetat and oxalate which is catalyzed by the oxaloacetate acetyl hydrolase.
# However, surprisingly by checking all reactions involved in both pathways from oxaloacetate and from citrate with the raw data in the model file, the last reaction step from glyoxylate to oxalate is not included. Therefore, this reaction has to be manually added to enable the assessment of both pathways. Then, for only analyzing the pathway starting from citric acid, the genes encoding for the enzyme malate dehydrogenase which catalyzes the reaction from oxaloacetate to malate was knocked out to only see the flux of glyoxylate to oxalate starting from citric acid.
#
#
# Pathway 1 --> "r51" Oxaloactate to Oxalic acid
#
#     3 reactions
#
# Pathway 2 --> "r52" Formate to Oxalic acid
#
#     1 reaction
#
# Pathway 3 --> "new" Citrate to Glyoxylate to Oxalic acid
#
# # 4.3 Strategies
#
# ## Changing media composition
#
# The media composition was changed, since the model includes glucose as the main carbon-source with a concentration of 10 g/L. However, the paper from “Oxalic acid production by Aspergillus niger” refers to the mentioned challenges discussed before in section 2, which occur while using the beneficial sucrose. They apply a concentration of 150 g/L. Therefore, the comparison has to be drawn between glucose and sucrose to see whether sucrose really has positive effects on growth rate and productivity.
#
# The given model uses a media composition including glucose with a of 10 mmol/g DCW * h. Here, a growth rate for Aspergillus niger of 0,94 h-1 and a productivity for r51 and the manually added reaction “GOOR” of 685,57 mmol / g DW * h and 120 mmol / g DW * h, respectively.
# By changing the media composition in a way that the glucose is exchanged by the same concentration of sucrose leads to an increase of growth rate and productivity. So, a growth rate of 1,88 h-1, which means an increase of 100%. Also, the productivity for both product formation reactions increased as a result of sucrose being the carbon source. R51 increased by 27% from 685,57 to 871,13 mmol / g DW * h, whereas GOOR increased by 100% from 120 to 240 mmol / g DW * h.
#
# Finally, the sucrose concentration was increased from 10 g/L up to 20 g/L to resemble the value which is stated in the paper “Oxalic acid production by Aspergillus niger”. Here, the trend that increasing sucrose concentrations increases the growth rate as well as the productivity is observed. Thus, increasing c(sucrose) by 15x leads to an increase of the growth rate by 1090 % from 1,88 h-1 to 22,38 h-1, whereas the productivities of r51 and GOOR increased by 60% from 871,13 to 1400 mmol / g DW * h and by 467% from 240 to 1362,5 mmol / g DW * h, respectively.
#
#
#
# ## Knockout of Extracellular Sucrose-degrading enzyme
#
# As already mentioned, one problem of the process is the low yield which results from fast glucose oxidation to gluconic acid. The sucrose is degraded by extracellular enzymes at the beginning of the fermentation, according to “Oxalic acid production by Aspergillus niger”. Therefore, knocking out those extracellular enzymes needs to be assessed.
#
# The “Invertase” reaction “r230a” has been identified as the decisive reaction for the extracellular degradation of sucrose to glucose.
#
# Thereafter, the genes 'inuE' and 'suc1' involved in the reaction were identified:
#
# Thereafter, both genes were knocked-out, respectively and analyzed whether the mutation is critical for the survival of the fungus. To establish the certain knockout separately without changing the model, the with command was used. To check whether the knocked-out genes are essential for the organism the slim_optimize command was used.
#
# Both printed outputs yielded a growth rate of 0,93985 / h which is no different to the growth rate of the native model. This hints towards the fact that the genes are not essential for the growth of the fungus and can be modified.
#
#
# ## Knockout of PP-shunt enzyme for flux of glucose to gluconic acid
#
# As already mentioned, starting from sucrose degradation, occurring glucose is quickly oxidized into gluconic acid which leads to a low yield. Therefore identifying the pathways involved in the flux from glucose to gluconic acid are identified and knocked out in this paragraph.
#
# The Kegg database characterized the oxidation of glucose to gluconic acid as being part of the pentose-phosphate shunt.
# In the model “r164a” for the oxidation of β-D-glucose to glucono-1,5-lactone and “NE6” for the spontaneous hydrolysis of lactone to D-Gluconate.
# Only reaction “r164a” gives available genes for knock-outs in the model as an output, therefore this reaction is the aim for interrupting the flux and therefore favoring the flux towards the product oxalate.
#
# Two genes were identified to be responsible for the oxidation reaction “r164a”, which entails the genes “goxAc” (ID: 1084421) and “GOD” (ID: 1132955). Again, both genes are knocked-out and evaluated in what extent they are essential for the fungus by running the slim_optimize command of the respective mutant:
#
#
#
# ## 4.4Plot phenotypic phase planes for relevant process conditions

# %% [markdown]
# ## 4.3 Calculate theoretical maximum yields for chosen product for suitable carbon sources

# %% [markdown]
# ## 5. Discussion (<500 words)

# %% [markdown]
# ## 6. Conclusion (<200 words)

# %% [markdown]
# ## References
# * [1] Fermentation parameter optimization of microbial oxalic acid production from cashew apple juice; Betiku, Eriola et al.; Heliyon, Volume 2, Issue 2, e00082; https://dx.doi.org/10.1016%2Fj.heliyon.2016.e00082
# * [2]  Pubchem chemical information about Oxalic Acid; https://pubchem.ncbi.nlm.nih.gov/compound/971
# * [3] Britannica Encyclopedia about Oxalic Acid; https://www.britannica.com/science/oxalic-acid
# * [4] Application of Oxalic Acid, Byjus; https://byjus.com/chemistry/uses-of-oxalic-acid/
# * [5]Pubchem chemical structure of Oxalic Acid; https://pubchem.ncbi.nlm.nih.gov/compound/Oxalic-acid#section=Structures
# * [6] Pau Loke Show, Kehinde Opeyemi Oladele, Qi Yan Siew, Fitri Abdul Aziz Zakry, John Chi-Wei Lan & Tau Chuan Ling (2015) Overview of citric acid production from Aspergillus niger, Frontiers in Life Science, 8:3, 271-283, DOI: 10.1080/21553769.2015.1033653
# * [7]Market report Oxalic Acid; Androit; https://www.adroitmarketresearch.com/industry-reports/oxalic-acid-market
# * [8]Oxalic Acid market research, Globe news wire, https://www.globenewswire.com/news-release/2019/10/09/1927512/0/en/Global-Oxalic-Acid-Market-Analysis-Trends-Forecasts-to-2025.html
# * [9] Prices for Oxalic Acid on the market, https://www.alibaba.com/trade/search?fsb=y&IndexArea=product_en&CatId=&SearchText=oxalic+acids
# * [10] Prices of sugar at the stock exchange, Wallstreet Online https://www.wallstreet-online.de/rohstoffe/zuckerpreis
# * [11] Schuster, .E., Dunn-Coleman, .N., Frisvad, .J. et al. On the safety of Aspergillus niger – a review. Appl Microbiol Biotechnol 59, 426–435 (2002). https://doi.org/10.1007/s00253-002-1032-6
# * [12] Cameselle, C., Bohlmann, J., Núñez, M. et al. Oxalic acid production by Aspergillus niger . Bioprocess Engineering 19, 247–252 (1998). https://doi.org/10.1007/PL00009017
# * [13] Poulsen, L., Thykær, J., & Eliasson Lantz, A. (2012). Regulatory processes in Aspergillus niger. Department of Systems Biology, Technical University of Denmark.
# * [14] Kobayashi, K., Hattori, T., Honda, Y. et al. Oxalic acid production by citric acid-producing Aspergillus niger overexpressing the oxaloacetate hydrolase gene oahA . J Ind Microbiol Biotechnol 41, 749–756 (2014). https://doi.org/10.1007/s10295-014-1419-2
# * [15] Brandl, J., Aguilar-Pontes, M.V., Schäpe, P. et al. A community-driven reconstruction of the Aspergillus niger metabolic network. Fungal Biol Biotechnol 5, 16 (2018). https://doi.org/10.1186/s40694-018-0060-7
# * [16] Cameselle, C., Bohlmann, J., Núñez, M. et al. Oxalic acid production by Aspergillus niger . Bioprocess Engineering 19, 247–252 (1998). https://doi.org/10.1007/PL00009017
# * [17] Lu H, Cao W, Ouyang L, Xia J, Huang M, Chu J, Zhuang Y, Zhang S, Noorman H. Comprehensive reconstruction and in silico analysis of Aspergillus niger genome-scale metabolic network model that accounts for 1210 ORFs. Biotechnol Bioeng. 2017 Mar;114(3):685-695. doi: 10.1002/bit.26195. Epub 2016 Oct 17. PMID: 27696371.
# * [18] Memote model analysis; Memote; https://memote.io/
# * [19] Pathways leading to Oxalic Acid; KEGG-database; https://www.genome.jp/kegg-bin/show_pathway?map00630
